# %%
# Dependencies
from splinter import Browser
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup

import requests

# %%
# !which chromedriver

# %%
# Setup splinter

executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# [WDM] - Current google-chrome version is 87.0.4280
# [WDM] - Get LATEST driver version for 87.0.4280
# [WDM] - Get LATEST driver version for 87.0.4280
# [WDM] - Trying to download new driver from http://chromedriver.storage.googleapis.com/87.0.4280.88/chromedriver_mac64.zip
# [WDM] - Driver has been saved in cache [/Users/raulacosta/.wdm/drivers/chromedriver/mac64/87.0.4280.88]

# %%
#Trip Advisor URL

url = "https://www.tripadvisor.com/Restaurants-g6787210-Morris_County_New_Jersey.html"
browser.visit(url)

# %%
#Lists for storing data 
name_list = []
price_list = []
rating_list = []
address_list = []

# %%
#Loop for all of the restaurants' names
for x in range(40):
    html = browser.html
    soup = BeautifulSoup(html,"html.parser")
    
    names = soup.find_all('div',class_= "wQjYiB7z")
   
    for result in names:
        try:
        
        
            restaurant = result.span.a.text
        
       # rating
        #adress
            print(restaurant)
        
        
    
        #if (name):
            #print(name)
        except AttributeError as e:
            print(e)
        
    try:
        
        browser.click_link_by_partial_text('Next')
        
        
    except:
        print("Done")
    #results = soup.find_all('div',class_= "_1llCuDZj")
# Out:
# 1. Gourmet Cafe Restaurant
# 2. Sergio and Co Italian Specialties
# 3. The Quiet Man
# 4. H2Ocean Restaurant & Raw Bar
# 5. La Strada Ristorante
# Parsippany's Best Pizza
# 6. Eccola
# 7. Hunan Taste Chinese Restaurant
# 8. Scalini Fedeli
# 9. Rod's Steak And Seafood Grille
# 10. Il Capriccio - NJ
# 11. The Committed Pig
# 12. Ruth's Chris Steak House
# 13. Arthur's Tavern
# 14. Slamwich Scratch Kitchen
# 15. Shanghai Jazz
# 16. Caffe Navona
# 17. Pompton Queen Diner
# 18. TABOR ROAD Tavern
# 19. Roots Steakhouse
# 20. Casa Bella Restaurant
# 21. Hibiscus Island Grill
# 22. Chef Fredy's Table
# 23. The Station at Mountain Lakes
# 24. Verona Restaurant
# 25. Restaurant Serenade
# 26. Thai Kitchen
# 27. Nonna's Italian Restaurant
# 28. South+Pine American Eatery
# 29. Thai Nam Phet
# 30. Thatcher McGhee's
# /Users/raulacosta/opt/anaconda3/lib/python3.8/site-packages/splinter/driver/webdriver/__init__.py:490: FutureWarning: browser.find_link_by_partial_text is deprecated. Use browser.links.find_by_partial_text instead.
#   warnings.warn(
# 1. Gourmet Cafe Restaurant
# 2. Sergio and Co Italian Specialties
# 3. The Quiet Man
# 4. H2Ocean Restaurant & Raw Bar
# 5. La Strada Ristorante
# Parsippany's Best Pizza
# 6. Eccola
# 7. Hunan Taste Chinese Restaurant
# 8. Scalini Fedeli
# 9. Rod's Steak And Seafood Grille
# 10. Il Capriccio - NJ
# 11. The Committed Pig
# 12. Ruth's Chris Steak House
# 13. Arthur's Tavern
# 14. Slamwich Scratch Kitchen
# 15. Shanghai Jazz
# 16. Caffe Navona
# 17. Pompton Queen Diner
# 18. TABOR ROAD Tavern
# 19. Roots Steakhouse
# 20. Casa Bella Restaurant
# 21. Hibiscus Island Grill
# 22. Chef Fredy's Table
# 23. The Station at Mountain Lakes
# 24. Verona Restaurant
# 25. Restaurant Serenade
# 26. Thai Kitchen
# 27. Nonna's Italian Restaurant
# 28. South+Pine American Eatery
# 29. Thai Nam Phet
# 30. Thatcher McGhee's
# Chef Fredy's Table
# 31. Marjan Fine Persian Grill
# 32. Denville Seafood & Codmother's Cafe
# 33. Rosie's Trattoria
# 34. Laku Sushi
# 35. The Famished Frog
# 616. Nathan's Famous
# 617. China King
# 618. Golden Burrito Mexican Spot
# 619. Lotus Thai Cuisine
# 620. Italian Table Trattoria / Pizza
# 621. Bally Dar Chinese Restaurant
# 622. Tierra's Y Sabores
# 623. Six West Bar and Grill
# 624. Anthony Franco's Ristorante & Pizzeria
# 625. Real Thai Halal
# 626. Ridgedale Diner Restaurant
# 627. Mirchi
# 628. Yangtze Kitchen
# 629. Hot Bagels and Deli
# 630. Pascarella Brothers Sandwich Shoppe

# %%
#Loop for Cuisine Type
for x in range(40):
    html = browser.html
    soup = BeautifulSoup(html,"html.parser")
    
    cuisine = soup.find_all('div',class_= "MIajtJFg _1cBs8huC _3d9EnJpt")
   
    for result in cuisine:
        try:
        
        
            cuisine_type = result.span.span.text
            
       # rating
        #adress
            print(cuisine_type)
        
        
    
     
        except AttributeError as e:
            print(e)
        
    try:
        
        browser.click_link_by_partial_text('Next')
        
        
    except:
        print("Done")
    #results = soup.find_all('div',class_= "_1llCuDZj")
# Out:
# American, Cajun & Creole
# 'NoneType' object has no attribute 'span'
# Mexican, Fast Food
# Asian, Korean
# Fast Food
# $$ - $$$
# Pizza, Italian
# Mediterranean, Greek
# 'NoneType' object has no attribute 'span'
# Chinese
# American, Cafe
# Cafe
# 'NoneType' object has no attribute 'span'
# Italian, Pizza
# $
# Barbecue, Asian
# Indian, Asian
# Fast Food
# Chinese
# $
# Thai
# Pizza, Seafood
# Chinese, Asian
# 'NoneType' object has no attribute 'span'
# Spanish
# 'NoneType' object has no attribute 'span'
# $$ - $$$
# American
# Indian, Asian
# Chinese
# $
# Deli
# American, Cajun & Creole
# 'NoneType' object has no attribute 'span'
# Mexican, Fast Food
# Asian, Korean
# Fast Food
# $$ - $$$
# Pizza, Italian
# Mediterranean, Greek
# 'NoneType' object has no attribute 'span'
# Chinese
# American, Cafe
# Cafe
# 'NoneType' object has no attribute 'span'
# Italian, Pizza
# $
# Barbecue, Asian
# Indian, Asian
# Fast Food
# Chinese
# $
# Thai
# Pizza, Seafood
# Chinese, Asian
# 'NoneType' object has no attribute 'span'
# Spanish
# 'NoneType' object has no attribute 'span'
# $$ - $$$
# American
# Indian, Asian
# Chinese
# $
# Deli
# American, Cajun & Creole
# 'NoneType' object has no attribute 'span'
# Mexican, Fast Food
# Asian, Korean
# Fast Food
# $$ - $$$
# Pizza, Italian
# Mediterranean, Greek
# 'NoneType' object has no attribute 'span'
# Chinese
# American, Cafe
# Cafe
# 'NoneType' object has no attribute 'span'
# Italian, Pizza
# $
# Barbecue, Asian
# Indian, Asian
# Fast Food
# Chinese
# $
# Thai
# Pizza, Seafood
# Chinese, Asian
# 'NoneType' object has no attribute 'span'
# Spanish
# 'NoneType' object has no attribute 'span'
# $$ - $$$
# American
# Indian, Asian
# Chinese
# $
# Deli
# American, Cajun & Creole
# 'NoneType' object has no attribute 'span'
# Mexican, Fast Food
# Asian, Korean
# Fast Food
# $$ - $$$
# Pizza, Italian
# Mediterranean, Greek
# 'NoneType' object has no attribute 'span'
# Chinese
# American, Cafe
# Cafe
# 'NoneType' object has no attribute 'span'
# Italian, Pizza
# $
# Barbecue, Asian
# Indian, Asian
# Fast Food
# Chinese
# $
# Thai
# Pizza, Seafood
# Chinese, Asian
# 'NoneType' object has no attribute 'span'
# Spanish
# 'NoneType' object has no attribute 'span'
# $$ - $$$
# American
# Indian, Asian
# Chinese
# $
# Deli
# American, Cajun & Creole
# 'NoneType' object has no attribute 'span'
# Mexican, Fast Food
# Asian, Korean
# Fast Food
# $$ - $$$
# Pizza, Italian
# Mediterranean, Greek
# 'NoneType' object has no attribute 'span'
# Chinese
# American, Cafe
# Cafe
# 'NoneType' object has no attribute 'span'
# Italian, Pizza
# $
# Barbecue, Asian
# Indian, Asian
# Fast Food
# Chinese
# $
# Thai
# Pizza, Seafood
# Chinese, Asian
# 'NoneType' object has no attribute 'span'
# Spanish
# 'NoneType' object has no attribute 'span'
# $$ - $$$
# American
# Indian, Asian
# Chinese
# $
# Deli
# American, Cajun & Creole
# 'NoneType' object has no attribute 'span'
# Mexican, Fast Food
# Asian, Korean
# Fast Food
# $$ - $$$
# Pizza, Italian
# Mediterranean, Greek
# 'NoneType' object has no attribute 'span'
# Chinese
# American, Cafe
# Cafe
# 'NoneType' object has no attribute 'span'
# Italian, Pizza
# $
# Barbecue, Asian
# Indian, Asian
# Fast Food
# Chinese
# $
# Thai
# Pizza, Seafood
# Chinese, Asian
# 'NoneType' object has no attribute 'span'
# Spanish
# 'NoneType' object has no attribute 'span'
# $$ - $$$
# American
# Indian, Asian
# Chinese
# $
# Deli
# American, Cajun & Creole
# 'NoneType' object has no attribute 'span'
# Mexican, Fast Food
# Asian, Korean
# Fast Food
# $$ - $$$
# Pizza, Italian
# Mediterranean, Greek
# 'NoneType' object has no attribute 'span'
# Chinese
# American, Cafe
# Cafe
# 'NoneType' object has no attribute 'span'
# Italian, Pizza
# $
# Barbecue, Asian
# Indian, Asian
# Fast Food
# Chinese
# $
# Thai
# Pizza, Seafood
# Chinese, Asian
# 'NoneType' object has no attribute 'span'
# Spanish
# 'NoneType' object has no attribute 'span'
# $$ - $$$
# American
# Indian, Asian
# Chinese
# $
# Deli
# American, Cajun & Creole
# 'NoneType' object has no attribute 'span'
# Mexican, Fast Food
# Asian, Korean
# Fast Food
# $$ - $$$
# Pizza, Italian
# Mediterranean, Greek
# 'NoneType' object has no attribute 'span'
# Chinese
# American, Cafe
# Cafe
# 'NoneType' object has no attribute 'span'
# Italian, Pizza
# $
# Barbecue, Asian
# Indian, Asian
# Fast Food
# Chinese
# $
# Thai
# Pizza, Seafood
# Chinese, Asian
# 'NoneType' object has no attribute 'span'
# Spanish
# 'NoneType' object has no attribute 'span'
# $$ - $$$
# American
# Indian, Asian
# Chinese
# $
# Deli
# American, Cajun & Creole
# 'NoneType' object has no attribute 'span'
# Mexican, Fast Food
# Asian, Korean
# Fast Food
# $$ - $$$
# Pizza, Italian
# Mediterranean, Greek
# 'NoneType' object has no attribute 'span'
# Chinese
# American, Cafe
# Cafe
# 'NoneType' object has no attribute 'span'
# Italian, Pizza
# $
# Barbecue, Asian
# Indian, Asian
# Fast Food
# Chinese
# $
# Thai
# Pizza, Seafood
# Chinese, Asian
# 'NoneType' object has no attribute 'span'
# Spanish
# 'NoneType' object has no attribute 'span'
# $$ - $$$
# American
# Indian, Asian
# Chinese
# $
# Deli
# American, Cajun & Creole
# 'NoneType' object has no attribute 'span'
# Mexican, Fast Food
# Asian, Korean
# Fast Food
# $$ - $$$
# Pizza, Italian
# Mediterranean, Greek
# 'NoneType' object has no attribute 'span'
# Chinese
# American, Cafe
# Cafe
# 'NoneType' object has no attribute 'span'
# Italian, Pizza
# $
# Barbecue, Asian
# Indian, Asian
# Fast Food
# Chinese
# $
# Thai
# Pizza, Seafood
# Chinese, Asian
# 'NoneType' object has no attribute 'span'
# Spanish
# 'NoneType' object has no attribute 'span'
# $$ - $$$
# American
# Indian, Asian
# Chinese
# $
# Deli
# American, Cajun & Creole
# 'NoneType' object has no attribute 'span'
# Mexican, Fast Food
# Asian, Korean
# Fast Food
# $$ - $$$
# Pizza, Italian
# Mediterranean, Greek
# 'NoneType' object has no attribute 'span'
# Chinese
# American, Cafe
# Cafe
# 'NoneType' object has no attribute 'span'
# Italian, Pizza
# $
# Barbecue, Asian
# Indian, Asian
# Fast Food
# Chinese
# $
# Thai
# Pizza, Seafood
# Chinese, Asian
# 'NoneType' object has no attribute 'span'
# Spanish
# 'NoneType' object has no attribute 'span'
# $$ - $$$
# American
# Indian, Asian
# Chinese
# $
# Deli
# American, Cajun & Creole
# 'NoneType' object has no attribute 'span'
# Mexican, Fast Food
# Asian, Korean
# Fast Food
# $$ - $$$
# Pizza, Italian
# Mediterranean, Greek
# 'NoneType' object has no attribute 'span'
# Chinese
# American, Cafe
# Cafe
# 'NoneType' object has no attribute 'span'
# Italian, Pizza
# $
# Barbecue, Asian
# Indian, Asian
# Fast Food
# Chinese
# $
# Thai
# Pizza, Seafood
# Chinese, Asian
# 'NoneType' object has no attribute 'span'
# Spanish
# 'NoneType' object has no attribute 'span'
# $$ - $$$
# American
# Indian, Asian
# Chinese
# $
# Deli
# American, Cajun & Creole
# 'NoneType' object has no attribute 'span'
# Mexican, Fast Food
# Asian, Korean
# Fast Food
# $$ - $$$
# Pizza, Italian
# Mediterranean, Greek
# 'NoneType' object has no attribute 'span'
# Chinese
# American, Cafe
# Cafe
# 'NoneType' object has no attribute 'span'
# Italian, Pizza
# $
# Barbecue, Asian
# Indian, Asian
# Fast Food
# Chinese
# $
# Thai
# Pizza, Seafood
# Chinese, Asian
# 'NoneType' object has no attribute 'span'
# Spanish
# 'NoneType' object has no attribute 'span'
# $$ - $$$
# American
# Indian, Asian
# Chinese
# $
# Deli
# American, Cajun & Creole
# 'NoneType' object has no attribute 'span'
# Mexican, Fast Food
# Asian, Korean
# Fast Food
# $$ - $$$
# Pizza, Italian
# Mediterranean, Greek
# 'NoneType' object has no attribute 'span'
# Chinese
# American, Cafe
# Cafe
# 'NoneType' object has no attribute 'span'
# Italian, Pizza
# $
# Barbecue, Asian
# Indian, Asian
# Fast Food
# Chinese
# $
# Thai
# Pizza, Seafood
# Chinese, Asian
# 'NoneType' object has no attribute 'span'
# Spanish
# 'NoneType' object has no attribute 'span'
# $$ - $$$
# American
# Indian, Asian
# Chinese
# $
# Deli
# American, Cajun & Creole
# 'NoneType' object has no attribute 'span'
# Mexican, Fast Food
# Asian, Korean
# Fast Food
# $$ - $$$
# Pizza, Italian
# Mediterranean, Greek
# 'NoneType' object has no attribute 'span'
# Chinese
# American, Cafe
# Cafe
# 'NoneType' object has no attribute 'span'
# Italian, Pizza
# $
# Barbecue, Asian
# Indian, Asian
# Fast Food
# Chinese
# $
# Thai
# Pizza, Seafood
# Chinese, Asian
# 'NoneType' object has no attribute 'span'
# Spanish
# 'NoneType' object has no attribute 'span'
# $$ - $$$
# American
# Indian, Asian
# Chinese
# $
# Deli
# American, Cajun & Creole
# 'NoneType' object has no attribute 'span'
# Mexican, Fast Food
# Asian, Korean
# Fast Food
# $$ - $$$
# Pizza, Italian
# Mediterranean, Greek
# 'NoneType' object has no attribute 'span'
# Chinese
# American, Cafe
# Cafe
# 'NoneType' object has no attribute 'span'
# Italian, Pizza
# $
# Barbecue, Asian
# Indian, Asian
# Fast Food
# Chinese
# $
# Thai
# Pizza, Seafood
# Chinese, Asian
# 'NoneType' object has no attribute 'span'
# Spanish
# 'NoneType' object has no attribute 'span'
# $$ - $$$
# American
# Indian, Asian
# Chinese
# $
# Deli
# American, Cajun & Creole
# 'NoneType' object has no attribute 'span'
# Mexican, Fast Food
# Asian, Korean
# Fast Food
# $$ - $$$
# Pizza, Italian
# Mediterranean, Greek
# 'NoneType' object has no attribute 'span'
# Chinese
# American, Cafe
# Cafe
# 'NoneType' object has no attribute 'span'
# Italian, Pizza
# $
# Barbecue, Asian
# Indian, Asian
# Fast Food
# Chinese
# $
# Thai
# Pizza, Seafood
# Chinese, Asian
# 'NoneType' object has no attribute 'span'
# Spanish
# 'NoneType' object has no attribute 'span'
# $$ - $$$
# American
# Indian, Asian
# Chinese
# $
# Deli
# American, Cajun & Creole
# 'NoneType' object has no attribute 'span'
# Mexican, Fast Food
# Asian, Korean
# Fast Food
# $$ - $$$
# Pizza, Italian
# Mediterranean, Greek
# 'NoneType' object has no attribute 'span'
# Chinese
# American, Cafe
# Cafe
# 'NoneType' object has no attribute 'span'
# Italian, Pizza
# $
# Barbecue, Asian
# Indian, Asian
# Fast Food
# Chinese
# $
# Thai
# Pizza, Seafood
# Chinese, Asian
# 'NoneType' object has no attribute 'span'
# Spanish
# 'NoneType' object has no attribute 'span'
# $$ - $$$
# American
# Indian, Asian
# Chinese
# $
# Deli
# American, Cajun & Creole
# 'NoneType' object has no attribute 'span'
# Mexican, Fast Food
# Asian, Korean
# Fast Food
# $$ - $$$
# Pizza, Italian
# Mediterranean, Greek
# 'NoneType' object has no attribute 'span'
# Chinese
# American, Cafe
# Cafe
# 'NoneType' object has no attribute 'span'
# Italian, Pizza
# $
# Barbecue, Asian
# Indian, Asian
# Fast Food
# Chinese
# $
# Thai
# Pizza, Seafood
# Chinese, Asian
# 'NoneType' object has no attribute 'span'
# Spanish
# 'NoneType' object has no attribute 'span'
# $$ - $$$
# American
# Indian, Asian
# Chinese
# $
# Deli
# American, Cajun & Creole
# 'NoneType' object has no attribute 'span'
# Mexican, Fast Food
# Asian, Korean
# Fast Food
# $$ - $$$
# Pizza, Italian
# Mediterranean, Greek
# 'NoneType' object has no attribute 'span'
# Chinese
# American, Cafe
# Cafe
# 'NoneType' object has no attribute 'span'
# Italian, Pizza
# $
# Barbecue, Asian
# Indian, Asian
# Fast Food
# Chinese
# $
# Thai
# Pizza, Seafood
# Chinese, Asian
# 'NoneType' object has no attribute 'span'
# Spanish
# 'NoneType' object has no attribute 'span'
# $$ - $$$
# American
# Indian, Asian
# Chinese
# $
# Deli
# American, Cajun & Creole
# 'NoneType' object has no attribute 'span'
# Mexican, Fast Food
# Asian, Korean
# Fast Food
# $$ - $$$
# Pizza, Italian
# Mediterranean, Greek
# 'NoneType' object has no attribute 'span'
# Chinese
# American, Cafe
# Cafe
# 'NoneType' object has no attribute 'span'
# Italian, Pizza
# $
# Barbecue, Asian
# Indian, Asian
# Fast Food
# Chinese
# $
# Thai
# Pizza, Seafood
# Chinese, Asian
# 'NoneType' object has no attribute 'span'
# Spanish
# 'NoneType' object has no attribute 'span'
# $$ - $$$
# American
# Indian, Asian
# Chinese
# $
# Deli
# American, Cajun & Creole
# 'NoneType' object has no attribute 'span'
# Mexican, Fast Food
# Asian, Korean
# Fast Food
# $$ - $$$
# Pizza, Italian
# Mediterranean, Greek
# 'NoneType' object has no attribute 'span'
# Chinese
# American, Cafe
# Cafe
# 'NoneType' object has no attribute 'span'
# Italian, Pizza
# $
# Barbecue, Asian
# Indian, Asian
# Fast Food
# Chinese
# $
# Thai
# Pizza, Seafood
# Chinese, Asian
# 'NoneType' object has no attribute 'span'
# Spanish
# 'NoneType' object has no attribute 'span'
# $$ - $$$
# American
# Indian, Asian
# Chinese
# $
# Deli
# American, Cajun & Creole
# 'NoneType' object has no attribute 'span'
# Mexican, Fast Food
# Asian, Korean
# Fast Food
# $$ - $$$
# Pizza, Italian
# Mediterranean, Greek
# 'NoneType' object has no attribute 'span'
# Chinese
# American, Cafe
# Cafe
# 'NoneType' object has no attribute 'span'
# Italian, Pizza
# $
# Barbecue, Asian
# Indian, Asian
# Fast Food
# Chinese
# $
# Thai
# Pizza, Seafood
# Chinese, Asian
# 'NoneType' object has no attribute 'span'
# Spanish
# 'NoneType' object has no attribute 'span'
# $$ - $$$
# American
# Indian, Asian
# Chinese
# $
# Deli
# American, Cajun & Creole
# 'NoneType' object has no attribute 'span'
# Mexican, Fast Food
# Asian, Korean
# Fast Food
# $$ - $$$
# Pizza, Italian
# Mediterranean, Greek
# 'NoneType' object has no attribute 'span'
# Chinese
# American, Cafe
# Cafe
# 'NoneType' object has no attribute 'span'
# Italian, Pizza
# $
# Barbecue, Asian
# Indian, Asian
# Fast Food
# Chinese
# $
# Thai
# Pizza, Seafood
# Chinese, Asian
# 'NoneType' object has no attribute 'span'
# Spanish
# 'NoneType' object has no attribute 'span'
# $$ - $$$
# American
# Indian, Asian
# Chinese
# $
# Deli
# American, Cajun & Creole
# 'NoneType' object has no attribute 'span'
# Mexican, Fast Food
# Asian, Korean
# Fast Food
# $$ - $$$
# Pizza, Italian
# Mediterranean, Greek
# 'NoneType' object has no attribute 'span'
# Chinese
# American, Cafe
# Cafe
# 'NoneType' object has no attribute 'span'
# Italian, Pizza
# $
# Barbecue, Asian
# Indian, Asian
# Fast Food
# Chinese
# $
# Thai
# Pizza, Seafood
# Chinese, Asian
# 'NoneType' object has no attribute 'span'
# Spanish
# 'NoneType' object has no attribute 'span'
# $$ - $$$
# American
# Indian, Asian
# Chinese
# $
# Deli
# American, Cajun & Creole
# 'NoneType' object has no attribute 'span'
# Mexican, Fast Food
# Asian, Korean
# Fast Food
# $$ - $$$
# Pizza, Italian
# Mediterranean, Greek
# 'NoneType' object has no attribute 'span'
# Chinese
# American, Cafe
# Cafe
# 'NoneType' object has no attribute 'span'
# Italian, Pizza
# $
# Barbecue, Asian
# Indian, Asian
# Fast Food
# Chinese
# $
# Thai
# Pizza, Seafood
# Chinese, Asian
# 'NoneType' object has no attribute 'span'
# Spanish
# 'NoneType' object has no attribute 'span'
# $$ - $$$
# American
# Indian, Asian
# Chinese
# $
# Deli
# American, Cajun & Creole
# 'NoneType' object has no attribute 'span'
# Mexican, Fast Food
# Asian, Korean
# Fast Food
# $$ - $$$
# Pizza, Italian
# Mediterranean, Greek
# 'NoneType' object has no attribute 'span'
# Chinese
# American, Cafe
# Cafe
# 'NoneType' object has no attribute 'span'
# Italian, Pizza
# $
# Barbecue, Asian
# Indian, Asian
# Fast Food
# Chinese
# $
# Thai
# Pizza, Seafood
# Chinese, Asian
# 'NoneType' object has no attribute 'span'
# Spanish
# 'NoneType' object has no attribute 'span'
# $$ - $$$
# American
# Indian, Asian
# Chinese
# $
# Deli
# American, Cajun & Creole
# 'NoneType' object has no attribute 'span'
# Mexican, Fast Food
# Asian, Korean
# Fast Food
# $$ - $$$
# Pizza, Italian
# Mediterranean, Greek
# 'NoneType' object has no attribute 'span'
# Chinese
# American, Cafe
# Cafe
# 'NoneType' object has no attribute 'span'
# Italian, Pizza
# $
# Barbecue, Asian
# Indian, Asian
# Fast Food
# Chinese
# $
# Thai
# Pizza, Seafood
# Chinese, Asian
# 'NoneType' object has no attribute 'span'
# Spanish
# 'NoneType' object has no attribute 'span'
# $$ - $$$
# American
# Indian, Asian
# Chinese
# $
# Deli
# American, Cajun & Creole
# 'NoneType' object has no attribute 'span'
# Mexican, Fast Food
# Asian, Korean
# Fast Food
# $$ - $$$
# Pizza, Italian
# Mediterranean, Greek
# 'NoneType' object has no attribute 'span'
# Chinese
# American, Cafe
# Cafe
# 'NoneType' object has no attribute 'span'
# Italian, Pizza
# $
# Barbecue, Asian
# Indian, Asian
# Fast Food
# Chinese
# $
# Thai
# Pizza, Seafood
# Chinese, Asian
# 'NoneType' object has no attribute 'span'
# Spanish
# 'NoneType' object has no attribute 'span'
# $$ - $$$
# American
# Indian, Asian
# Chinese
# $
# Deli
# American, Cajun & Creole
# 'NoneType' object has no attribute 'span'
# Mexican, Fast Food
# Asian, Korean
# Fast Food
# $$ - $$$
# Pizza, Italian
# Mediterranean, Greek
# 'NoneType' object has no attribute 'span'
# Chinese
# American, Cafe
# Cafe
# 'NoneType' object has no attribute 'span'
# Italian, Pizza
# $
# Barbecue, Asian
# Indian, Asian
# Fast Food
# Chinese
# $
# Thai
# Pizza, Seafood
# Chinese, Asian
# 'NoneType' object has no attribute 'span'
# Spanish
# 'NoneType' object has no attribute 'span'
# $$ - $$$
# American
# Indian, Asian
# Chinese
# $
# Deli
# American, Cajun & Creole
# 'NoneType' object has no attribute 'span'
# Mexican, Fast Food
# Asian, Korean
# Fast Food
# $$ - $$$
# Pizza, Italian
# Mediterranean, Greek
# 'NoneType' object has no attribute 'span'
# Chinese
# American, Cafe
# Cafe
# 'NoneType' object has no attribute 'span'
# Italian, Pizza
# $
# Barbecue, Asian
# Indian, Asian
# Fast Food
# Chinese
# $
# Thai
# Pizza, Seafood
# Chinese, Asian
# 'NoneType' object has no attribute 'span'
# Spanish
# 'NoneType' object has no attribute 'span'
# $$ - $$$
# American
# Indian, Asian
# Chinese
# $
# Deli
# American, Cajun & Creole
# 'NoneType' object has no attribute 'span'
# Mexican, Fast Food
# Asian, Korean
# Fast Food
# $$ - $$$
# Pizza, Italian
# Mediterranean, Greek
# 'NoneType' object has no attribute 'span'
# Chinese
# American, Cafe
# Cafe
# 'NoneType' object has no attribute 'span'
# Italian, Pizza
# $
# Barbecue, Asian
# Indian, Asian
# Fast Food
# Chinese
# $
# Thai
# Pizza, Seafood
# Chinese, Asian
# 'NoneType' object has no attribute 'span'
# Spanish
# 'NoneType' object has no attribute 'span'
# $$ - $$$
# American
# Indian, Asian
# Chinese
# $
# Deli
# American, Cajun & Creole
# 'NoneType' object has no attribute 'span'
# Mexican, Fast Food
# Asian, Korean
# Fast Food
# $$ - $$$
# Pizza, Italian
# Mediterranean, Greek
# 'NoneType' object has no attribute 'span'
# Chinese
# American, Cafe
# Cafe
# 'NoneType' object has no attribute 'span'
# Italian, Pizza
# $
# Barbecue, Asian
# Indian, Asian
# Fast Food
# Chinese
# $
# Thai
# Pizza, Seafood
# Chinese, Asian
# 'NoneType' object has no attribute 'span'
# Spanish
# 'NoneType' object has no attribute 'span'
# $$ - $$$
# American
# Indian, Asian
# Chinese
# $
# Deli
# American, Cajun & Creole
# 'NoneType' object has no attribute 'span'
# Mexican, Fast Food
# Asian, Korean
# Fast Food
# $$ - $$$
# Pizza, Italian
# Mediterranean, Greek
# 'NoneType' object has no attribute 'span'
# Chinese
# American, Cafe
# Cafe
# 'NoneType' object has no attribute 'span'
# Italian, Pizza
# $
# Barbecue, Asian
# Indian, Asian
# Fast Food
# Chinese
# $
# Thai
# Pizza, Seafood
# Chinese, Asian
# 'NoneType' object has no attribute 'span'
# Spanish
# 'NoneType' object has no attribute 'span'
# $$ - $$$
# American
# Indian, Asian
# Chinese
# $
# Deli
# American, Cajun & Creole
# 'NoneType' object has no attribute 'span'
# Mexican, Fast Food
# Asian, Korean
# Fast Food
# $$ - $$$
# Pizza, Italian
# Mediterranean, Greek
# 'NoneType' object has no attribute 'span'
# Chinese
# American, Cafe
# Cafe
# 'NoneType' object has no attribute 'span'
# Italian, Pizza
# $
# Barbecue, Asian
# Indian, Asian
# Fast Food
# Chinese
# $
# Thai
# Pizza, Seafood
# Chinese, Asian
# 'NoneType' object has no attribute 'span'
# Spanish
# 'NoneType' object has no attribute 'span'
# $$ - $$$
# American
# Indian, Asian
# Chinese
# $
# Deli
# American, Cajun & Creole
# 'NoneType' object has no attribute 'span'
# Mexican, Fast Food
# Asian, Korean
# Fast Food
# $$ - $$$
# Pizza, Italian
# Mediterranean, Greek
# 'NoneType' object has no attribute 'span'
# Chinese
# American, Cafe
# Cafe
# 'NoneType' object has no attribute 'span'
# Italian, Pizza
# $
# Barbecue, Asian
# Indian, Asian
# Fast Food
# Chinese
# $
# Thai
# Pizza, Seafood
# Chinese, Asian
# 'NoneType' object has no attribute 'span'
# Spanish
# 'NoneType' object has no attribute 'span'
# $$ - $$$
# American
# Indian, Asian
# Chinese
# $
# Deli
# American, Cajun & Creole
# 'NoneType' object has no attribute 'span'
# Mexican, Fast Food
# Asian, Korean
# Fast Food
# $$ - $$$
# Pizza, Italian
# Mediterranean, Greek
# 'NoneType' object has no attribute 'span'
# Chinese
# American, Cafe
# Cafe
# 'NoneType' object has no attribute 'span'
# Italian, Pizza
# $
# Barbecue, Asian
# Indian, Asian
# Fast Food
# Chinese
# $
# Thai
# Pizza, Seafood
# Chinese, Asian
# 'NoneType' object has no attribute 'span'
# Spanish
# 'NoneType' object has no attribute 'span'
# $$ - $$$
# American
# Indian, Asian
# Chinese
# $
# Deli
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-120d654e3928> in <module>
#       2 for x in range(40):
#       3     html = browser.html
# ----> 4     soup = BeautifulSoup(html,"html.parser")
#       5
#       6     cuisine = soup.find_all('div',class_= "MIajtJFg _1cBs8huC _3d9EnJpt")
#
# ~/opt/anaconda3/lib/python3.8/site-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     343             self.reset()
#     344             try:
# --> 345                 self._feed()
#     346                 success = True
#     347                 break
#
# ~/opt/anaconda3/lib/python3.8/site-packages/bs4/__init__.py in _feed(self)
#     429         self.builder.reset()
#     430
# --> 431         self.builder.feed(self.markup)
#     432         # Close out any unfinished strings and close all the open tags.
#     433         self.endData()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/bs4/builder/_htmlparser.py in feed(self, markup)
#     375         parser.soup = self.soup
#     376         try:
# --> 377             parser.feed(markup)
#     378             parser.close()
#     379         except HTMLParseError as e:
#
# ~/opt/anaconda3/lib/python3.8/html/parser.py in feed(self, data)
#     109         """
#     110         self.rawdata = self.rawdata + data
# --> 111         self.goahead(0)
#     112
#     113     def close(self):
#
# ~/opt/anaconda3/lib/python3.8/html/parser.py in goahead(self, end)
#     169             if startswith('<', i):
#     170                 if starttagopen.match(rawdata, i): # < + letter
# --> 171                     k = self.parse_starttag(i)
#     172                 elif startswith("</", i):
#     173                     k = self.parse_endtag(i)
#
# ~/opt/anaconda3/lib/python3.8/html/parser.py in parse_starttag(self, i)
#     343             self.handle_startendtag(tag, attrs)
#     344         else:
# --> 345             self.handle_starttag(tag, attrs)
#     346             if tag in self.CDATA_CONTENT_ELEMENTS:
#     347                 self.set_cdata_mode(tag)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/bs4/builder/_htmlparser.py in handle_starttag(self, name, attrs, handle_empty_element)
#     149         #print("START", name)
#     150         sourceline, sourcepos = self.getpos()
# --> 151         tag = self.soup.handle_starttag(
#     152             name, None, None, attr_dict, sourceline=sourceline,
#     153             sourcepos=sourcepos
#
# ~/opt/anaconda3/lib/python3.8/site-packages/bs4/__init__.py in handle_starttag(self, name, namespace, nsprefix, attrs, sourceline, sourcepos)
#     687             return None
#     688
# --> 689         tag = self.element_classes.get(Tag, Tag)(
#     690             self, self.builder, name, namespace, nsprefix, attrs,
#     691             self.currentTag, self._most_recent_element,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/bs4/element.py in __init__(self, parser, builder, name, namespace, prefix, attrs, parent, previous, is_xml, sourceline, sourcepos, can_be_empty_element, cdata_list_attributes, preserve_whitespace_tags)
#    1126         self.attrs = attrs
#    1127         self.contents = []
# -> 1128         self.setup(parent, previous)
#    1129         self.hidden = False
#    1130
#
# ~/opt/anaconda3/lib/python3.8/site-packages/bs4/element.py in setup(self, parent, previous_element, next_element, previous_sibling, next_sibling)
#     191         if (previous_sibling is None
#     192             and self.parent is not None and self.parent.contents):
# --> 193             previous_sibling = self.parent.contents[-1]
#     194
#     195         self.previous_sibling = previous_sibling
#
# KeyboardInterrupt:

# %%
cuisine = soup.find_all('div',class_= "MIajtJFg _1cBs8huC _3d9EnJpt")
print(cuisine)
# Out:
# [<div class="MIajtJFg _1cBs8huC _3d9EnJpt"><span class="EHA742uW"><span class="_1p0FLy4t">Italian</span></span><span class="EHA742uW"><span class="_1p0FLy4t">$$ - $$$</span></span><span class="_3iSfzjbL"><span><span class="MUNBf8J0 _2npzmCBq"><span class="jxNFpwcl"><svg class="_2HBN-k68 _2JndpOur" height="1em" viewbox="0 0 24 24" width="1em"><path d="M19.5 2h-15c-.3 0-.5.2-.5.5v19c0 .3.2.5.5.5h15c.3 0 .5-.2.5-.5v-19c0-.3-.2-.5-.5-.5zM12 10.2V12c0 .2-.2.4-.4.4h-1.4v5.3c0 .2-.2.399-.4.399h-.6c-.2.001-.4-.199-.4-.399v-5.3H7.4c-.2 0-.4-.2-.4-.4V6.4c0-.2.2-.4.4-.4h.5c.2 0 .4.2.4.4v3.9H8.9V6.4c0-.2.2-.4.4-.4h.5c.2 0 .4.2.4.4v3.9h.6V6.4c0-.2.2-.4.4-.4h.5c.2 0 .3.2.3.4v3.8zm5 7.4c0 .2-.2.4-.4.4h-.7c-.2 0-.4-.2-.4-.4v-5.3h-1.1c-.2 0-.4-.2-.4-.4V7.4v-.1c0-.7.7-1.3 1.5-1.3s1.5.6 1.5 1.4v10.2z"></path></svg></span>Menu</span></span></span><span></span></div>, <div class="MIajtJFg _1cBs8huC _3d9EnJpt"><span class="EHA742uW"><span class="_1p0FLy4t">Italian</span></span><span class="EHA742uW"><span class="_1p0FLy4t">$$ - $$$</span></span><span class="_3iSfzjbL"><span><span class="MUNBf8J0"><span class="jxNFpwcl"><svg class="_2HBN-k68 _2JndpOur" height="1em" viewbox="0 0 24 24" width="1em"><path d="M19.5 2h-15c-.3 0-.5.2-.5.5v19c0 .3.2.5.5.5h15c.3 0 .5-.2.5-.5v-19c0-.3-.2-.5-.5-.5zM12 10.2V12c0 .2-.2.4-.4.4h-1.4v5.3c0 .2-.2.399-.4.399h-.6c-.2.001-.4-.199-.4-.399v-5.3H7.4c-.2 0-.4-.2-.4-.4V6.4c0-.2.2-.4.4-.4h.5c.2 0 .4.2.4.4v3.9H8.9V6.4c0-.2.2-.4.4-.4h.5c.2 0 .4.2.4.4v3.9h.6V6.4c0-.2.2-.4.4-.4h.5c.2 0 .3.2.3.4v3.8zm5 7.4c0 .2-.2.4-.4.4h-.7c-.2 0-.4-.2-.4-.4v-5.3h-1.1c-.2 0-.4-.2-.4-.4V7.4v-.1c0-.7.7-1.3 1.5-1.3s1.5.6 1.5 1.4v10.2z"></path></svg></span>Menu<svg class="_2HBN-k68 _2JndpOur" height="1em" viewbox="0 0 24 24" width="1em"><path d="M7.561 15.854l-1.415-1.415 8.293-8.293H7.854v-2h10v10h-2V7.561z"></path></svg></span></span></span></div>, <div class="MIajtJFg _1cBs8huC _3d9EnJpt"><span class="EHA742uW"><span class="_1p0FLy4t">American, Irish</span></span><span class="EHA742uW"><span class="_1p0FLy4t">$$ - $$$</span></span><span class="_3iSfzjbL"><span><span class="MUNBf8J0 _2npzmCBq"><span class="jxNFpwcl"><svg class="_2HBN-k68 _2JndpOur" height="1em" viewbox="0 0 24 24" width="1em"><path d="M19.5 2h-15c-.3 0-.5.2-.5.5v19c0 .3.2.5.5.5h15c.3 0 .5-.2.5-.5v-19c0-.3-.2-.5-.5-.5zM12 10.2V12c0 .2-.2.4-.4.4h-1.4v5.3c0 .2-.2.399-.4.399h-.6c-.2.001-.4-.199-.4-.399v-5.3H7.4c-.2 0-.4-.2-.4-.4V6.4c0-.2.2-.4.4-.4h.5c.2 0 .4.2.4.4v3.9H8.9V6.4c0-.2.2-.4.4-.4h.5c.2 0 .4.2.4.4v3.9h.6V6.4c0-.2.2-.4.4-.4h.5c.2 0 .3.2.3.4v3.8zm5 7.4c0 .2-.2.4-.4.4h-.7c-.2 0-.4-.2-.4-.4v-5.3h-1.1c-.2 0-.4-.2-.4-.4V7.4v-.1c0-.7.7-1.3 1.5-1.3s1.5.6 1.5 1.4v10.2z"></path></svg></span>Menu</span></span></span><span></span></div>, <div class="MIajtJFg _1cBs8huC _3d9EnJpt"><span class="EHA742uW"><span class="_1p0FLy4t">American, Seafood</span></span><span class="EHA742uW"><span class="_1p0FLy4t">$$$$</span></span></div>, <div class="MIajtJFg _1cBs8huC _3d9EnJpt"><span class="EHA742uW"><span class="_1p0FLy4t">Italian, European</span></span><span class="EHA742uW"><span class="_1p0FLy4t">$$ - $$$</span></span><span class="_3iSfzjbL"><span><span class="MUNBf8J0 _2npzmCBq"><span class="jxNFpwcl"><svg class="_2HBN-k68 _2JndpOur" height="1em" viewbox="0 0 24 24" width="1em"><path d="M19.5 2h-15c-.3 0-.5.2-.5.5v19c0 .3.2.5.5.5h15c.3 0 .5-.2.5-.5v-19c0-.3-.2-.5-.5-.5zM12 10.2V12c0 .2-.2.4-.4.4h-1.4v5.3c0 .2-.2.399-.4.399h-.6c-.2.001-.4-.199-.4-.399v-5.3H7.4c-.2 0-.4-.2-.4-.4V6.4c0-.2.2-.4.4-.4h.5c.2 0 .4.2.4.4v3.9H8.9V6.4c0-.2.2-.4.4-.4h.5c.2 0 .4.2.4.4v3.9h.6V6.4c0-.2.2-.4.4-.4h.5c.2 0 .3.2.3.4v3.8zm5 7.4c0 .2-.2.4-.4.4h-.7c-.2 0-.4-.2-.4-.4v-5.3h-1.1c-.2 0-.4-.2-.4-.4V7.4v-.1c0-.7.7-1.3 1.5-1.3s1.5.6 1.5 1.4v10.2z"></path></svg></span>Menu</span></span></span><span></span></div>, <div class="MIajtJFg _1cBs8huC _3d9EnJpt"><span class="EHA742uW"><span class="_1p0FLy4t">Pizza, Italian</span></span><span class="EHA742uW"><span class="_1p0FLy4t">$$ - $$$</span></span><span class="_3iSfzjbL"> ...

# %%
for result in cuisine:
    try:
        
        
        cuisine_type = result.span.span.text
        price = result
       # rating
        #adress
        print(cuisine_type)
        
        
    
        #if (name):
            #print(name)
    except AttributeError as e:
        print(e)
# Out:
# Italian
# Italian
# American, Irish
# American, Seafood
# Italian, European
# Pizza, Italian
# Italian
# Chinese, Asian
# Italian
# American, Steakhouse
# Italian
# American, Bar
# American, Steakhouse
# American, Steakhouse
# American
# Chinese, Asian
# Italian
# American, Diner
# American, Bar
# American, Steakhouse
# Italian
# Caribbean, Jamaican
# American, Cajun & Creole
# American
# Italian
# American
# Asian, Thai
# Italian, Pizza
# American
# Asian, Thai
# Irish, Bar

# %%
cuisine_price = soup.find_all('span',class_= "_1p0FLy4t")
print(cuisine_price)
# Out:
# [<span class="_1p0FLy4t"><span><a class="_2uEVo25r" href="/Restaurant_Review-g60906-d648367-Reviews-Chef_Fredy_s_Table-Morristown_Morris_County_New_Jersey.html#REVIEWS" target="_blank"><span class="_141TBKA-"><svg aria-label="4.5 of 5 bubbles" class="_3KcXyP0F" height="16" title="4.5 of 5 bubbles" viewbox="0 0 120 24" width="80"><path d="M10.25 1.75a10.25 10.25 0 110 20.5 10.25 10.25 0 110-20.5m24 0a10.25 10.25 0 110 20.5 10.25 10.25 0 110-20.5m24 0a10.25 10.25 0 110 20.5 10.25 10.25 0 110-20.5m24 0a10.25 10.25 0 110 20.5 10.25 10.25 0 110-20.5m24 0a10.25 10.25 0 110 20.5 10.25 10.25 0 110-20.5m0 2.5a5.25 5.25 0 110 15.5"></path></svg></span><span class="w726Ki5B">236 reviews</span></a></span></span>, <span class="_1p0FLy4t">Closed Now</span>, <span class="_1p0FLy4t">American, Cajun &amp; Creole</span>, <span class="_1p0FLy4t">$$$$</span>, <span class="_1p0FLy4t"><span><a class="_2uEVo25r" href="/Restaurant_Review-g46547-d4915591-Reviews-Howard_s_Bagels_Gourmet_Deli-Lake_Hiawatha_Morris_County_New_Jersey.html#REVIEWS" target="_blank"><span class="_141TBKA-"><svg aria-label="4.5 of 5 bubbles" class="_3KcXyP0F" height="16" title="4.5 of 5 bubbles" viewbox="0 0 120 24" width="80"><path d="M10.25 1.75a10.25 10.25 0 110 20.5 10.25 10.25 0 110-20.5m24 0a10.25 10.25 0 110 20.5 10.25 10.25 0 110-20.5m24 0a10.25 10.25 0 110 20.5 10.25 10.25 0 110-20.5m24 0a10.25 10.25 0 110 20.5 10.25 10.25 0 110-20.5m24 0a10.25 10.25 0 110 20.5 10.25 10.25 0 110-20.5m0 2.5a5.25 5.25 0 110 15.5"></path></svg></span><span class="w726Ki5B">5 reviews</span></a></span></span>, <span class="_1p0FLy4t">Closed Now</span>, <span class="_1p0FLy4t"><span><a class="_2uEVo25r" href="/Restaurant_Review-g46783-d4942349-Reviews-Qdoba_Mexican_Grill-Rockaway_Morris_County_New_Jersey.html#REVIEWS" target="_blank"><span class="_141TBKA-"><svg aria-label="4.0 of 5 bubbles" class="_3KcXyP0F" height="16" title="4.0 of 5 bubbles" viewbox="0 0 120 24" width="80"><path d="M10.25 1.75a10.25 10.25 0 110 20.5 10.25 10.25 0 110-20.5m24 0a10.25 10.25 0 110 20.5 10.25 10.25 0 110-20.5m24 0a10.25 10.25 0 110 20.5 10.25 10.25 0 110-20.5m24 0a10.25 10.25 0 110 20.5 10.25 10.25 0 110-20.5m24 0a10.25 10.25 0 110 20.5 10.25 10.25 0 110-20.5m0 2.5a5.25 5.25 0 110 15.5 5.25 5.25 0 110-15.5"></path></svg></span><span class="w726Ki5B">13 reviews</span></a></span></span>, <span class="_1p0FLy4t">Mexican, Fast Food</span>, <span class="_1p0FLy4t"><span><a class="_2uEVo25r" href="/Restaurant_Review-g46401-d8753633-Reviews-So_Gong_Dong-East_Hanover_Morris_County_New_Jersey.html#REVIEWS" target="_blank"><span class="_141TBKA-"><svg aria-label="4.0 of 5 bubbles" class="_3KcXyP0F" height="16" title="4.0 of 5 bubbles" viewbox="0 0 120 24" width="80"><path d="M10.25 1.75a10.25 10.25 0 110 20.5 10.25 10.25 0 110-20.5m24 0a10.25 10.25 0 110 20.5 10.25 10.25 0 110-20.5m24 0a10.25 10.25 0 110 20.5 10.25 10.25 0 110-20.5m24 0a10.25 10.25 0 110 20.5 10.25 10.25 0 110-20.5m24 0a10.25 10.25 0 110 20.5 10.25 10.25 0 110-20.5m0 2.5a5.25 5.25 0 110 15.5 5.25 5.25 0 110-15.5"></path></svg></span><span class="w726Ki5B">17 reviews</span></a></span></span>, <span class="_1p0FLy4t">Asian, Korean</span>, <span class="_1p0FLy4t">$$ - $$$</span>, <span class="_1p0FLy4t"><span><a class="_2uEVo25r" href="/Restaurant_Review-g46639-d5083284-Reviews-Montville_Bagels_and_Deli-Montville_Morris_County_New_Jersey.html#REVIEWS" target="_blank"><span class="_141TBKA-"><svg aria-label="3.5 of 5 bubbles" class="_3KcXyP0F" height="16" title="3.5 of 5 bubbles" viewbox="0 0 120 24" width="80"><path d="M10.25 1.75a10.25 10.25 0 110 20.5 10.25 10.25 0 110-20.5m24 0a10.25 10.25 0 110 20.5 10.25 10.25 0 110-20.5m24 0a10.25 10.25 0 110 20.5 10.25 10.25 0 110-20.5m24 0a10.25 10.25 0 110 20.5 10.25 10.25 0 110-20.5m0 2.5a5.25 5.25 0 110 15.5m24-18a10.25 10.25 0 110 20.5 10.25 10.25 0 110-20.5m0 2.5a5.25 5.25 0 110 15.5 5.25 5.25 0 110-15.5"></path></svg></span><span class="w726Ki5B">13 reviews</span></a></span></span>, <span class="_1p0FLy4t" ...

# %%
for result in cuisine_price:
    try:
        
        
        price = result.text.split()
        
        
        
       # rating
        #adress
        print(price)
        
        
    
        #if (name):
            #print(name)
    except AttributeError as e:
        print(e)
# Out:
# ['236', 'reviews']
# ['Closed', 'Now']
# ['American,', 'Cajun', '&', 'Creole']
# ['$$$$']
# ['5', 'reviews']
# ['Closed', 'Now']
# ['13', 'reviews']
# ['Mexican,', 'Fast', 'Food']
# ['17', 'reviews']
# ['Asian,', 'Korean']
# ['$$', '-', '$$$']
# ['13', 'reviews']
# ['Closed', 'Now']
# ['Fast', 'Food']
# ['$']
# ['5', 'reviews']
# ['$$', '-', '$$$']
# ['34', 'reviews']
# ['Closed', 'Now']
# ['Pizza,', 'Italian']
# ['$$', '-', '$$$']
# ['8', 'reviews']
# ['Mediterranean,', 'Greek']
# ['$']
# ['4', 'reviews']
# ['Closed', 'Now']
# ['8', 'reviews']
# ['Open', 'Now']
# ['Chinese']
# ['5', 'reviews']
# ['American,', 'Cafe']
# ['9', 'reviews']
# ['Cafe']
# ['$$', '-', '$$$']
# ['4', 'reviews']
# ['15', 'reviews']
# ['Closes', 'in', '14', 'min']
# ['Italian,', 'Pizza']
# ['$']
# ['10', 'reviews']
# ['$']
# ['28', 'reviews']
# ['Closed', 'Now']
# ['Barbecue,', 'Asian']
# ['$$', '-', '$$$']
# ['16', 'reviews']
# ['Closes', 'in', '14', 'min']
# ['Indian,', 'Asian']
# ['$$', '-', '$$$']
# ['6', 'reviews']
# ['Fast', 'Food']
# ['10', 'reviews']
# ['Closes', 'in', '14', 'min']
# ['Chinese']
# ['$']
# ['4', 'reviews']
# ['Closed', 'Now']
# ['$']
# ['7', 'reviews']
# ['Thai']
# ['$$', '-', '$$$']
# ['5', 'reviews']
# ['Pizza,', 'Seafood']
# ['$$', '-', '$$$']
# ['11', 'reviews']
# ['Closes', 'in', '14', 'min']
# ['Chinese,', 'Asian']
# ['4', 'reviews']
# ['Open', 'Now']
# ['12', 'reviews']
# ['Spanish']
# ['$$', '-', '$$$']
# ['3', 'reviews']
# ['7', 'reviews']
# ['Closed', 'Now']
# ['$$', '-', '$$$']
# ['6', 'reviews']
# ['American']
# ['$']
# ['18', 'reviews']
# ['Indian,', 'Asian']
# ['$$', '-', '$$$']
# ['10', 'reviews']
# ['Open', 'Now']
# ['Chinese']
# ['$$', '-', '$$$']
# ['8', 'reviews']
# ['Closed', 'Now']
# ['$']
# ['5', 'reviews']
# ['Deli']

# %%
#rating

# %%
#address

# %%
#website
